# %% [markdown]
# >[1-1](#updateTitle=true&folderId=1TOgNRnWunbUNzCmXagRv9CRmvNLuVDMV&scrollTo=98wiWmOD8VuA)
#
# >>[クジラWeb API](#updateTitle=true&folderId=1TOgNRnWunbUNzCmXagRv9CRmvNLuVDMV&scrollTo=cWMxPUGl3g9D)
#
# >[1-2](#updateTitle=true&folderId=1TOgNRnWunbUNzCmXagRv9CRmvNLuVDMV&scrollTo=-GaCZorb8fTM)
#
# >>[BeautifulSoup利用](#updateTitle=true&folderId=1TOgNRnWunbUNzCmXagRv9CRmvNLuVDMV&scrollTo=Dx3BcVqn82NE)
#
# >>[BeautifulSoupとクジラWeb API](#updateTitle=true&folderId=1TOgNRnWunbUNzCmXagRv9CRmvNLuVDMV&scrollTo=JTOEz3Eq_Rkl)
#
# >>[BeautifulSoupとYahoo!ファイナンス](#updateTitle=true&folderId=1TOgNRnWunbUNzCmXagRv9CRmvNLuVDMV&scrollTo=AxsnLQsvCFZ1)
#
# >>[BeautifulSoupとクジラWeb API](#updateTitle=true&folderId=1TOgNRnWunbUNzCmXagRv9CRmvNLuVDMV&scrollTo=IYwhiqT5DJUJ)
#
# >[1-3](#updateTitle=true&folderId=1TOgNRnWunbUNzCmXagRv9CRmvNLuVDMV&scrollTo=5X1_Z8JwDM1r)

# %% [markdown]
# # 1-1

# %%
# ライブラリの取り込み --- (※1)
import urllib.request

# URLと保存パスを指定
url = "http://uta.pw/shodou/img/28/214.png"
savename = "test.png"

# ダウンロード --- (※2)
urllib.request.urlretrieve(url, savename)
print("保存しました")
# Out:
# 保存しました

# %%
import urllib.request 

# URLと保存パスを指定
url = "http://uta.pw/shodou/img/28/214.png"
savename = "test.png"

# ダウンロード --- (※1)
mem = urllib.request.urlopen(url).read()

# ファイルへ保存 --- (※2)
with open(savename, mode="wb") as f:
    f.write(mem)
    print("保存しました")
# Out:
# 保存しました

# %% [markdown]
# ## [クジラWeb API](http://api.aoikujira.com/)
# * 上記サイトのAPI（例「IP確認API」）を利用。
# * APIの利用方法等記載あり。

# %%
# IP確認APIへアクセスして結果を表示する

# モジュールを取り込む --- (※1)
import urllib.request

# データを取得する --- (※2)
url = "http://api.aoikujira.com/ip/ini"
res = urllib.request.urlopen(url)
data = res.read()

# バイナリを文字列に変換 --- (※3)
text = data.decode("utf-8")
print(text)
# Out:
# [ip]
# API_URI=http://api.aoikujira.com/ip/get.php
# REMOTE_ADDR=35.227.150.89
# REMOTE_HOST=89.150.227.35.bc.googleusercontent.com
# REMOTE_PORT=56465
# HTTP_HOST=api.aoikujira.com
# HTTP_USER_AGENT=Python-urllib/3.6
# HTTP_ACCEPT_LANGUAGE=
# HTTP_ACCEPT_CHARSET=
# SERVER_PORT=80
# FORMAT=ini

# %%
import urllib.request
import urllib.parse

API = "http://api.aoikujira.com/zip/xml/get.php"

# パラメータをURLエンコードする --- (※1)
values = {
    'fmt': 'xml',
    'zn': '1500042'
}
params = urllib.parse.urlencode(values)

# リクエスト用のURLを生成 --- (※2)
url = API + "?" + params
print("url=", url)

# ダウンロード --- (※3)
data = urllib.request.urlopen(url).read()
text = data.decode("utf-8")
print(text)
# Out:
# url= http://api.aoikujira.com/zip/xml/get.php?fmt=xml&zn=1500042
# <?xml version="1.0" encoding="utf-8" ?>
# <address result="1">
# <header>
#   <result>1</result>
#   <api>api.aoikujira.com/zip</api>
#   <version>1.1</version>
# </header>
# <value>
#   <zip>1500042</zip>
#   <ken>東京都</ken>
#   <shi>渋谷区</shi>
#   <cho>宇田川町</cho>
#   <disp>東京都渋谷区宇田川町</disp>
#   <kenkana>トウキョウト</kenkana>
#   <shikana>シブヤク</shikana>
#   <chokana>ウダガワチョウ</chokana>
# </value>
# </address>

# %%
#!/usr/bin/env python3

# ライブラリの取り込み --- (※1)
import sys
import urllib.request as req
import urllib.parse as parse

# コマンドライン引数を得る --- (※2)
"""
if len(sys.argv) <= 1:
    print("USAGE: hyakunin.py (keyword)")
    sys.exit()
keyword = sys.argv[1]
"""
# コマンドライン引数がない場合
# # # # # # # # # # # # # # # # 
keyword = "春の日"
# # # # # # # # # # # # # # # # 

# パラメータをURLエンコードする --- (※3)
API = "http://api.aoikujira.com/hyakunin/get.php"
query = {
    "fmt": "ini",
    "key": keyword
}
params = parse.urlencode(query)
url = API + "?" + params 
print("url=", url)

# ダウンロード --- (※4)
with req.urlopen(url) as r:
    b = r.read()
    data = b.decode('utf-8')
    print(data)
# Out:
# url= http://api.aoikujira.com/hyakunin/get.php?fmt=ini&key=%E6%98%A5%E3%81%AE%E6%97%A5
# [item33]
# kami=久方の 光のどけき 春の日に
# simo=しづ心なく 花の散るらむ
# kami_kana=ひさかたのひかりのとけきはるのひに
# simo_kana=しつこころなくはなのちるらむ
# sakusya=紀友則

# %% [markdown]
# # 1-2

# %% [markdown]
# ## BeautifulSoup利用

# %%
# ライブラリを取り込む --- (※1)
from bs4 import BeautifulSoup 

# 解析したいHTML --- (※2)
html = """
<html><body>
  <h1>スクレイピングとは？</h1>
  <p>Webページを解析すること。</p>
  <p>任意の箇所を抽出すること。</p>
</body></html>
"""

# HTMLを解析する --- (※3)
soup = BeautifulSoup(html, 'html.parser')

# 任意の部分を抽出する --- (※4)
h1 = soup.html.body.h1
p1 = soup.html.body.p
p2 = p1.next_sibling.next_sibling

# 要素のテキストを表示する --- (※5)
print("h1 = " + h1.string)
print("p  = " + p1.string)
print("p  = " + p2.string)
# Out:
# h1 = スクレイピングとは？
# p  = Webページを解析すること。
# p  = 任意の箇所を抽出すること。

# %% [markdown]
# ↑`p2 = p1.next_sibling.next_sibling`が手動的すぎる

# %%
from bs4 import BeautifulSoup 

html = """
<html><body>
  <h1 id="title">スクレイピングとは？</h1>
  <p id="body">Webページから任意のデータを抽出すること</p>
</body></html>
"""

# HTMLを解析する --- (※1)
soup = BeautifulSoup(html, 'html.parser')

# find()メソッドで取り出す --- (※2)
title = soup.find(id="title")
body  = soup.find(id="body")

# テキスト部分を表示 
print("#title=" + title.string)
print("#body="  + body.string)
# Out:
# #title=スクレイピングとは？
# #body=Webページから任意のデータを抽出すること

# %%
from bs4 import BeautifulSoup 

html = """
<html><body>
  <ul>
    <li><a href="http://uta.pw">uta</a></li>
    <li><a href="http://oto.chu.jp">oto</a></li>
  </ul>
</body></html>
"""

# HTMLを解析する --- (※1)
soup = BeautifulSoup(html, 'html.parser')

# findAll()メソッドで取り出す --- (※2)
links = soup.find_all("a")

# リンク一覧を表示 --- (※3)
for a in links:
    href = a.attrs['href']
    text = a.string
    print(text, ">", href)
# Out:
# uta > http://uta.pw
# oto > http://oto.chu.jp

# %% [markdown]
# ## BeautifulSoupと[クジラWeb API](http://api.aoikujira.com/)

# %%
from bs4 import BeautifulSoup
import urllib.request as req

url = "http://api.aoikujira.com/zip/xml/1500042"

# urlopen()でデータを取得 --- (※1)
res = req.urlopen(url)

# BeautifulSoupで解析 --- (※2)
soup = BeautifulSoup(res, "html.parser")

# 任意のデータを抽出 --- (※3)
ken = soup.find("ken").string
shi = soup.find("shi").string
cho = soup.find("cho").string
print(ken, shi, cho)
# Out:
# 東京都 渋谷区 宇田川町

# %%
from bs4 import BeautifulSoup 

# 解析対象となるHTML --- (※1)
html = """
<html><body>
<div id="meigen">
  <h1>トルストイの名言</h1>
  <ul class="items">
    <li>汝の心に教えよ、心に学ぶな</li>
    <li>謙虚な人は誰からも好かれる。</li>
    <li>強い人々は、いつも気取らない。</li>
  </ul>
</div>
</body></html>
"""

# HTMLを解析する --- (※2)
soup = BeautifulSoup(html, 'html.parser')

# 必要な部分をCSSクエリで取り出す
# | タイトル部分を取得 --- (※3)
h1 = soup.select_one("div#meigen > h1").string
print("h1 =", h1)

# | リスト部分を取得 --- (※4)
li_list = soup.select("div#meigen > ul.items > li")
for li in li_list:
	print("li =", li.string)
# Out:
# h1 = トルストイの名言
# li = 汝の心に教えよ、心に学ぶな
# li = 謙虚な人は誰からも好かれる。
# li = 強い人々は、いつも気取らない。

# %% [markdown]
# ## BeautifulSoupと[Yahoo!ファイナンス](https://stocks.finance.yahoo.co.jp/stocks/detail/?code=usdjpy)
#
# ```
# # これはコードとして書式設定されます
# ```

# %%
from bs4 import BeautifulSoup
import urllib.request as req

# HTMLを取得
url = "http://stocks.finance.yahoo.co.jp/stocks/detail/?code=usdjpy"
res = req.urlopen(url)

# HTMLを解析
soup = BeautifulSoup(res, "html.parser")

# 任意のデータを抽出 --- (※1)
price = soup.select_one(".stoksPrice").string
print("usd/jpy=", price)
# Out:
# usd/jpy= 106.820000

# %% [markdown]
# ## BeautifulSoupと[クジラWeb API](http://api.aoikujira.com/)

# %%
from bs4 import BeautifulSoup
import urllib.request as req

# 為替情報XMLを取得
url = "http://api.aoikujira.com/kawase/xml/usd"
res = req.urlopen(url)

# HTMLを解析
soup = BeautifulSoup(res, "html.parser")

# 任意のデータを抽出 --- (※1)
jpy = soup.select_one("jpy").string
print("usd/jpy=", jpy)
# Out:
# usd/jpy= 106.87468

# %% [markdown]
# # 1-3
